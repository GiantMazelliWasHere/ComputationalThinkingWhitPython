# %%
pip install pandas

# %%
pip install -U scikit-learn scipy matplotlib

# %%
import pandas as pd

# %%
df = pd.read_csv(r'./manutencao_preditiva.csv')

# %%
df
# Out:
#         UDI ID Produto Tipo  Temperatura Ar [K]  Temperatura Processo [K]  \
# 0         1     M14860    M               298.1                     308.6
# 1         2     L47181    L               298.2                     308.7
# 2         3     L47182    L               298.1                     308.5
# 3         4     L47183    L               298.2                     308.6
# 4         5     L47184    L               298.2                     308.7
# ...     ...        ...  ...                 ...                       ...
# 9995   9996     M24855    M               298.8                     308.4
# 9996   9997     H39410    H               298.9                     308.4
# 9997   9998     M24857    M               299.0                     308.6
# 9998   9999     H39412    H               299.0                     308.7
# 9999  10000     M24859    M               299.0                     308.7
#
#       Velocidade Rotacao [rpm]  Torque [Nm]  Desgaste Ferramenta [min]  Alvo  \
# ...

# %%
#selecionar dados e input e output

#inputs
x = df[[
    'Temperatura Ar [K]', 'Temperatura Processo [K]', 'Velocidade Rotacao [rpm]', 'Torque [Nm]', 'Desgaste Ferramenta [min]']]

#output
y = df['Tipo da Falha']

# %%
# Selecionar dados para testar um IA

from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_texte = train_test_split(x, y, test_size=0.3)

# %%
x_treino
# Out:
#       Temperatura Ar [K]  Temperatura Processo [K]  Velocidade Rotacao [rpm]  \
# 9968               298.4                     308.0                      1605
# 6126               300.9                     310.9                      1370
# 4954               303.7                     312.6                      1702
# 184                298.2                     308.2                      1667
# 1778               298.6                     308.2                      1325
# ...                  ...                       ...                       ...
# 8356               298.6                     309.6                      1344
# 7227               299.7                     309.6                      1720
# 8162               299.6                     311.0                      1574
# 1621               297.7                     307.6                      1844
# 4980               303.7                     312.8                      1685
#
#       Torque [Nm]  Desgaste Ferramenta [min]
# ...

# %%
# Parametros de treinamento

from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(100), max_iter=100,activation='relu')
mlp
# Out:
# MLPClassifier(hidden_layer_sizes=100, max_iter=100)

# %%
# Treino do modelo

treino = mlp.fit(x_treino, y_treino)

# %%
y_pred_treino = mlp.predict(x_treino)
y_pred_teste = mlp.predict(x_teste)

# %%
y_pred_teste
# Out:
# array(['No Failure', 'No Failure', 'No Failure', ..., 'No Failure',
#        'No Failure', 'No Failure'], dtype='<U24')

# %% [markdown]
# # Usando Interrow em Python

# %%
data = {
    "Primeiro_nome":['João', 'Ana', 'Laura'],
    "Idade":[16, 29, 20]
}

df = pd.DataFrame(data)
df
# Out:
#   Primeiro_nome  Idade
# 0          João     16
# 1           Ana     29
# 2         Laura     20

# %%
for index, row in df.iterrows():
    print(row['Primeiro_nome'], row['Idade'])
# Out:
# João 16
# Ana 29
# Laura 20

# %%
for index, row in df.iterrows():
    print(f'Linha {index}:')
    print(f"Nome: {row['Primeiro_nome']}, Idade: {row['Idade']}")
# Out:
# Linha 0:
# Nome: João, Idade: 16
# Linha 1:
# Nome: Ana, Idade: 29
# Linha 2:
# Nome: Laura, Idade: 20

# %%
df = pd.read_csv(r'./manutencao_preditiva.csv')
df

# %% [markdown]
# ## 1. Faça a iteração usando iterrows para o dataframe falha das máquinas. Print as variáveis UDI, ID do produto e tipo

# %%
for index, row in df.iterrows():
    print(f'Linha {index}:')
    print(f"UDI: {row['UDI']}, ID do produto: {row['ID Produto']} e Tipo: {row['Tipo']}")

# %% [markdown]
# ## 2. Como utlizar a estrutura de condição usando iterrows?

# %%
for index, row in df.iterrows():
    if row['Tipo'] == 'M':
        print(f'Linha {index}:')
        print(f"UDI: {row['UDI']}, ID do produto: {row['ID Produto']} e Tipo: {row['Tipo']}")

# %% [markdown]
# ## 3. Selecione apenas os dados do tipo H e print as variaveis UDI, ID do produto e tipo.

# %%
for index, row in df.iterrows():
    if row['Tipo'] == 'H':
        print(f'Linha {index}:')
        print(f"UDI: {row['UDI']}, ID do produto: {row['ID Produto']} e Tipo: {row['Tipo']}")

# %% [markdown]
# ## 4. Selecione apenas os dados do tipo H e M e print as variaveis Temperatura Ar, processos, Velocidade de rotação e torque

# %%
for index, row in df.iterrows():
    if row['Tipo'] == 'H' or row['Tipo'] == 'M':
        print(f'Linha {index}:')
        print(f"Temperatura Ar: {row['Temperatura Ar [K]']}, Temperatura Processo: {row['Temperatura Processo [K]']}, Velocidade Rotacao: {row['Velocidade Rotacao [rpm]']} e Torque: {row['Torque [Nm]']}")

# %% [markdown]
# ## 5. Mostre as informações de temperatura de ar e processo apenas para as maquinas do tipo L e H

# %%
for index, row in df.iterrows():
    if row['Tipo'] == 'M' or row['Tipo'] == 'L':
        print(f'Linha {index}:')
        print(f"Temperatura Ar: {row['Temperatura Ar [K]']}, Temperatura Processo: {row['Temperatura Processo [K]']}")

# %% [markdown]
# ## 6. Crie um programa para mostrar um texto: esté é um tipo de máquina M. Caso seja do tipo H, escreva está máquina é do tipo H. Caso contrario, escreva este é um item de outro tipo

# %%
for index, row in df.iterrows():
    if row['Tipo'] == 'M':
        print(f"Esta é uma máquinha do tipo: {row['Tipo']}")
    elif row['Tipo'] == 'H':
        print(f"Esta é uma máquinha do tipo: {row['Tipo']}")
    else:
        print('Está maquina é de outro tipo')

# %% [markdown]
# ## 7. Mostre a mesma informações do exercícios anterior porém, selecione apenas temperaturas do ar mair que 300.

# %%
for index, row in df.iterrows():
    if row['Tipo'] == 'M':
        print(f"Esta é uma máquinha do tipo: {row['Tipo']}")
    elif row['Tipo'] == 'H':
        print(f"Esta é uma máquinha do tipo: {row['Tipo']}")
    else:
        print('Máquinas de outro tipo')

    if row['Temperatura Ar [K]'] >= 300:
        print("Máquinas com alta temperatura\n")
    else:
        print('Máquinas com baixa temperatura\n')

# %% [markdown]
# ## 8. Crie uma estrutura para mostrar as informações de velocidade de rotação e torqe. Porém, escreva 'tempratura alta de processo' quando a temperatura do processo for maior que  média e a 'temperatura baixa de processo' quando for menor que a média

# %%
media = df['Temperatura Processo [K]'].mean()

for index, row in df.iterrows():
    if row['Temperatura Processo [K]'] > media:
        print(f'Linha {index}:')
        print(f"Velocidade de rotação: {row['Velocidade Rotacao [rpm]']} e Torque: {row['Torque [Nm]']}")
        print('Temperatura alta de processo')
    else:
        print(f'Linha {index}:')
        print(f"Velocidade de rotação: {row['Velocidade Rotacao [rpm]']} e Torque: {row['Torque [Nm]']}")
        print('Temperatura baixa de processo')

# %% [markdown]
# ## 9. Crie um programa para identificar e mostrar a quantidade de falhas no conjnto de dados.

# %%
contagem_falhas = {}

for index, row in df.iterrows():
    tipo_falha = row['Tipo da Falha']

    if tipo_falha in contagem_falhas:
        contagem_falhas[tipo_falha] += 1

    else:
        contagem_falhas[tipo_falha] = 1

for tipo_falha, contagem in contagem_falhas.items():
    print(f"Tipo da falha: {tipo_falha} - Quantidade: {contagem}")
# Out:
# Tipo da falha: No Failure - Quantidade: 9652
# Tipo da falha: Power Failure - Quantidade: 95
# Tipo da falha: Tool Wear Failure - Quantidade: 45
# Tipo da falha: Overstrain Failure - Quantidade: 78
# Tipo da falha: Random Failures - Quantidade: 18
# Tipo da falha: Heat Dissipation Failure - Quantidade: 112

# %% [markdown]
# ## 10. Alterer o código anterior para contar a quantidade de mapquinas no conjunto de dados.

# %%
contagem_maquinas = {}

for index, row in df.iterrows():
    tipo_maquina = row['Tipo']

    if tipo_maquina in contagem_maquinas:
        contagem_maquinas[tipo_maquina] += 1

    else:
        contagem_maquinas[tipo_maquina] = 1

for tipo_maquina, contagem in contagem_maquinas.items():
    print(f"Tipo {tipo_maquina} - Quantidade: {contagem}")
# Out:
# Tipo M - Quantidade: 2997
# Tipo L - Quantidade: 6000
# Tipo H - Quantidade: 1003

# %% [markdown]
# ## Estrutura com "While"

# %%
data = {
    "Primeiro_nome":['João', 'Ana', 'Laura'],
    "Idade":[16, 29, 20]
}

df = pd.DataFrame(data)
df
# Out:
#   Primeiro_nome  Idade
# 0          João     16
# 1           Ana     29
# 2         Laura     20

# %%
iterator = df.iterrows()

while True:
    try:
        index, row = next(iterator)
        print(row['Primeiro_nome'], row['Idade'])
    except StopIteration:
        break
# Out:
# João 16
# Ana 29
# Laura 20

# %%
iterator = df.iterrows()

while True:
    try:
        index, row = next(iterator)
        print(f"Linha {index}:")
        print(f"Nome: {row['Primeiro_nome']} e Idade: {row['Idade']} anos")
    except StopIteration:
        break
# Out:
# Linha 0:
# Nome: João e Idade: 16 anos
# Linha 1:
# Nome: Ana e Idade: 29 anos
# Linha 2:
# Nome: Laura e Idade: 20 anos

# %%
df = pd.read_csv(r'./manutencao_preditiva.csv')
df
# Out:
#         UDI ID Produto Tipo  Temperatura Ar [K]  Temperatura Processo [K]  \
# 0         1     M14860    M               298.1                     308.6
# 1         2     L47181    L               298.2                     308.7
# 2         3     L47182    L               298.1                     308.5
# 3         4     L47183    L               298.2                     308.6
# 4         5     L47184    L               298.2                     308.7
# ...     ...        ...  ...                 ...                       ...
# 9995   9996     M24855    M               298.8                     308.4
# 9996   9997     H39410    H               298.9                     308.4
# 9997   9998     M24857    M               299.0                     308.6
# 9998   9999     H39412    H               299.0                     308.7
# 9999  10000     M24859    M               299.0                     308.7
#
#       Velocidade Rotacao [rpm]  Torque [Nm]  Desgaste Ferramenta [min]  Alvo  \
# ...

# %%
df.columns
# Out:
# Index(['UDI', 'ID Produto', 'Tipo', 'Temperatura Ar [K]',
#        'Temperatura Processo [K]', 'Velocidade Rotacao [rpm]', 'Torque [Nm]',
#        'Desgaste Ferramenta [min]', 'Alvo', 'Tipo da Falha'],
#       dtype='object')

# %% [markdown]
# ## 11. Crie um programa para apresentar as informações de UDI e ID produto quando houver apenas falhas do tipo no failure.

# %%
iterator = df.iterrows()

while True:
    try:
        index, row = next(iterator)
        if row['Tipo da Falha'] == 'No Failure':
            print(f"Linha {index}:")
            print(f"UDI: {row['UDI']}, ID Produto: {row['ID Produto']} e Torque: {row['Torque [Nm]']}")
    except StopIteration:
        break

# %% [markdown]
# ## 12. Crie um programa para apresentar a quantidade de falhas no conjunto de dados de falhas em máquinas usando estrtura while

# %%
contagem_falhas = {}
iterator = df.iterrows()

while True:
    try:
        index, row = next(iterator)
        tipo_falha = row['Tipo da Falha']

        if tipo_falha in contagem_falhas:
            contagem_falhas[tipo_falha] += 1
        else:
            contagem_falhas[tipo_falha] = 1

    except StopIteration:
        break


for tipo_falha, contagem in contagem_falhas.items():
    print(f"Tipo da falha: {tipo_falha} - Quantidade: {contagem}")
# Out:
# Tipo da falha: No Failure - Quantidade: 9652
# Tipo da falha: Power Failure - Quantidade: 95
# Tipo da falha: Tool Wear Failure - Quantidade: 45
# Tipo da falha: Overstrain Failure - Quantidade: 78
# Tipo da falha: Random Failures - Quantidade: 18
# Tipo da falha: Heat Dissipation Failure - Quantidade: 112

# %% [markdown]
# ## Calculando a média usando for e while

# %%
#for

soma_desgaste = 0
count_m = 0

for index, row in df.iterrows():
    if row['Tipo'] == 'M':
        soma_desgaste += row['Desgaste Ferramenta [min]']
        count_m += 1
    
if count_m > 0:
    media_desgaste = soma_desgaste / count_m
    print(f"A média de desgaste da ferramente para o tipo M é: {media_desgaste}")
else:
    print('Não há dados')
# Out:
# A média de desgaste da ferramente para o tipo M é: 107.27227227227228

# %%
#while

soma_desgaste = 0
count_m = 0
iterator = df.iterrows()

while True:
    try:
        index, row = next(iterator)
        if row['Tipo'] == 'M':
            soma_desgaste += row['Desgaste Ferramenta [min]']
            count_m += 1
    except StopIteration:
        break
    
if count_m > 0:
    media_desgaste = soma_desgaste / count_m
    print(f"A média de desgaste da ferramente para o tipo M é: {media_desgaste}")
else:
    print('Não há dados')
# Out:
# A média de desgaste da ferramente para o tipo M é: 107.27227227227228
